# %%
f = open("text.txt","r")
print(f.read())
f.close()
# Out:
# Hi this is a demo file and i am trying to read the content of this file.

# %%
f = open("text.txt", "a")
f.write("\nThis is a new line.")
f.close()

# %%
with open("text.txt", "r") as f:
    print(f.read())
# Out:
# Hi this is a demo file and i am trying to read the content of this file.
# This is a new line.
